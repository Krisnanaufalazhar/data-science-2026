# %%
# =====================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# Portofolio Data Science
# Nama : Krisna Naufal Azhar Suhendar
# NIM : 240401070506
# Kelas : IF 405
# Program Studi : PJJ Informatika
# =====================================================



# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel dan tipe data dasar
nama     = "KRISNA NAUFAL AZHAR SUHENDAR"   # String
angkatan = 2024                     # Integer
ipk      = 4.00                     # Float
aktif    = True                     # Boolean

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")

# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")

# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Halo semuanya! Perkenalkan, saya Krisna Naufal Azhar Suhendar, mahasiswa Informatika angkatan 2024. Pada mata kuliah Pengantar Data Science ini, saya berharap dapat memahami dasar-dasar pengolahan data, analisis, serta penggunaan tools seperti Python untuk mengolah data menjadi informasi yang bermanfaat."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("KRISNA NAUFAL AZHAR SUHENDAR", "Informatika", 2024)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama     : KRISNA NAUFAL AZHAR SUHENDAR
# Angkatan : 2024
# IPK      : 4.0
# Aktif    : True
#
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub
# Hai! Saya KRISNA NAUFAL AZHAR SUHENDAR dari Informatika, angkatan 2024.

# %% [markdown]
# # Kesimpulan
#
# Pada Pertemuan 1, saya mempelajari dasar-dasar pemrograman Python yang digunakan dalam Data Science. Materi yang dipelajari meliputi penggunaan output dengan `print()`, variabel dan tipe data dasar (string, integer, float, dan boolean), penggunaan list, perulangan `for`, serta pembuatan fungsi sederhana.
#
# Dari praktikum ini saya memahami bahwa Python merupakan bahasa pemrograman yang mudah dipelajari dan banyak digunakan dalam pengolahan data. Materi dasar ini menjadi fondasi penting untuk mempelajari analisis data dan Data Science pada pertemuan-pertemuan berikutnya.
#
# Keterbatasan yang masih saya rasakan adalah perlunya latihan lebih lanjut untuk memahami penggunaan fungsi dan struktur data yang lebih kompleks.
